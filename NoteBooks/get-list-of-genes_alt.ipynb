# %% [markdown]
# # Summary
# Show how to retrieve list of genes for specified organisms
#
# ## Workflow
#
# For a given assembly `accession.version`
# * Get a ref-seq id for assembly
# * Get a nuccore id for refseq-id
# * List all gene-ids for a assembly by its nuccoreid
# * For each gene
#     * Get gene info and display it
#     * Get some pubmed relateed information

# %%
import requests
import xml.etree.ElementTree as xml
from IPython.display import HTML, display
from Bio import Entrez

#email Set the Entrez email parameter (default is not set).
Entrez.email = "great_team@hackathon.ncbi.org"

#tool Set the Entrez tool parameter (default is biopython).
Entrez.tool = "hackathon_examples"

def get_nuccore_id(uid):
    """
    Get nuccore id by its refseq id.
    """
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi'
    params = {'dbfrom': 'assembly', 'db':'nuccore', 'retmode':'json', 'id': uid}
    r = requests.get(url, params=params)
    if r.status_code != 200:
        raise Exception("Cant nuccore id for specified assembly")
    doc = r.json()['linksets'][0]['linksetdbs']
    for link in doc:
        if link['linkname'] == "assembly_nuccore_refseq":
            return int(link['links'][0])
    else:
        return int(doc[0]['links'][0])

    
def list_gene_ids(nuc_id):
    """
    List genes for specified organism nuccore id.
    """
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi'
    params = {'dbfrom':'nuccore', 'db': 'gene', 'retmode': 'json', 'id':nuc_id}
    r = requests.get(url, params=params)
    if r.status_code != 200:
        raise Exception("Cant find annotation")
    return r.json()['linksets'][0]['linksetdbs'][0]['links']


def list_gene_ids_alt(refseq_id):
    """
    List genes for specified organism nuccore id.
    """
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi'
    params = {'dbfrom':'assembly', 'db': 'genome', 'retmode': 'json', 'id':refseq_id}
    r = requests.get(url, params=params)
    if r.status_code != 200:
        raise Exception("Cant find refseq")
    genome_id = r.json()['linksets'][0]['linksetdbs'][0]['links'][0]
    
    
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi'
    params = {'dbfrom':'genome', 'db': 'gene', 'retmode': 'json', 'id':genome_id}
    r = requests.get(url, params=params)
    if r.status_code != 200:
        raise Exception("Cant find annotation")
   
    return r.json()['linksets'][0]['linksetdbs'][0]['links']


def get_asm_details(accession):
    """
    Get ref_seq id and organism name for specified assembly.
    """
    params = {'release':accession}
    r = requests.get(
        'https://www.ncbi.nlm.nih.gov/projects/r_gencoll/asm4portal/gc_assembly_svc.cgi',
        params=params)
    if r.status_code != 200:
        raise Exception("Cant find assembly")
    doc = r.content.decode('utf-8')
    root = xml.fromstring(doc)
    refseq_id = int(root.attrib['uid'])
    header = root.find('header')
    organism_name = header.find('species-organism').text
    return refseq_id, organism_name


def build_gene_table(genes, max_show, organism_name):
    """
    Build html table listing gene names, proteins and publication numbers.
    """

    html = "<table>"

    html += "<tr>"       
    html += "<th> Gene Tag </th>"
    html += "<th> Gene Locus </th>"
    html += "<th> Protein </th>"
    html += "<th> Protein sequence </th>"
    html += "<th> Number of Pubmed publications </th>"
    html += "</tr>"
    
    for gene in genes[0:max_show]:
        handle = Entrez.efetch(db="gene", id=gene, retmode="xml")
        doc = handle.read()
        root = xml.fromstring(doc)
        gene_node = root.find('Entrezgene')
        gene_ref = gene_node.find('Entrezgene_gene').find('Gene-ref')
        
        locus_at = gene_ref.find('Gene-ref_locus')
        locus_tag = gene_ref.find('Gene-ref_locus-tag')

        terms = []
        locus = "n/a"
        tag = "n/a"

        try:
            tag = locus_tag.text
            terms.append(tag)
        except:
            pass
        
        try:
            locus = locus_at.text
            terms.append(locus)
        except:
            pass
        
        prot_node = gene_node.find('Entrezgene_prot')
        
        prot = "n/a"
        
        if prot_node:
            prot = prot_node.find('Prot-ref').find('Prot-ref_name').find('Prot-ref_name_E').text
            terms.append(prot)
            
            
        loc_node = gene_node.find('Entrezgene_locus')
        com = loc_node.find('Gene-commentary')
        prod = com.find('Gene-commentary_products')
        prod_seq = "n/a"
        prod_ver = "n/a"
        if prod:
            prod_com = prod.find('Gene-commentary')
            if prod_com:
                prod_seq = prod_com.find('Gene-commentary_accession').text
                prod_ver = prod_com.find('Gene-commentary_version').text
                terms.append(prod_seq)
            
        # Lookup pubs
        query = " or ".join(["'%s'" % (i) for i in terms])
        handle = Entrez.esearch(db="pubmed",term="(" + query + ") and '"+ organism_name + "'")
        search_results =Entrez.read(handle)

        html += "<tr>"
        
        html += "<td>" + tag + "</td>"
        html += "<td>" + locus + "</td>"
        html += "<td>" + prot + "</td>"
        html += "<td>" + prod_seq + "." + prod_ver + "</td>"
        html += "<td>" + str(search_results['Count']) + "</td>" 

        html += "</tr>"
    html += "</table>"

    if len(genes) > max_show:
        html += "<p>And " + str(len(genes) - max_show) + " more... </p>"
        
    return html


def list_genes(accession, max_show = 100, look_gene_groups=False):
    """
    For the given organism assembly build a table with first few genes.
    """
    refseq_id, organism_name = get_asm_details(accession)

    html = "<h1>" + organism_name + "</h1>"
    
    handle = Entrez.esearch(db="pubmed",term="'" + organism_name + "'")
    search_results =Entrez.read(handle)

    html += "<p>" + str(search_results['Count']) + " pubmeds found</p>" 

    if look_gene_groups:
        genes = list_gene_ids_alt(refseq_id)
    else:
        nuccore_id = get_nuccore_id(refseq_id)
        genes = list_gene_ids(nuccore_id)
        
        
    html += "<h3> Genes: </h3>"
    
    html += build_gene_table(genes, max_show, organism_name)    

    display(HTML(html))

# %%
# %%time

list_genes('GCF_000013425.1', 5, False)
# Out:
# False
# <?xml version="1.0" ?>
# <!DOCTYPE Entrezgene-Set PUBLIC "-//NLM//DTD NCBI-Entrezgene, 21st January 2005//EN" "https://www.ncbi.nlm.nih.gov/data_specs/dtd/NCBI_Entrezgene.dtd">
# <Entrezgene-Set>
# <Entrezgene>
#   <Entrezgene_track-info>
#     <Gene-track>
#       <Gene-track_geneid>16830705</Gene-track_geneid>
#       <Gene-track_create-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2013</Date-std_year>
#               <Date-std_month>9</Date-std_month>
#               <Date-std_day>11</Date-std_day>
#               <Date-std_hour>18</Date-std_hour>
#               <Date-std_minute>20</Date-std_minute>
#               <Date-std_second>0</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_create-date>
#       <Gene-track_update-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2016</Date-std_year>
#               <Date-std_month>4</Date-std_month>
#               <Date-std_day>14</Date-std_day>
#               <Date-std_hour>21</Date-std_hour>
#               <Date-std_minute>4</Date-std_minute>
#               <Date-std_second>48</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_update-date>
#     </Gene-track>
#   </Entrezgene_track-info>
#   <Entrezgene_type value="protein-coding">6</Entrezgene_type>
#   <Entrezgene_source>
#     <BioSource>
#       <BioSource_genome value="chromosome">21</BioSource_genome>
#       <BioSource_org>
#         <Org-ref>
#           <Org-ref_taxname>Staphylococcus aureus subsp. aureus NCTC 8325</Org-ref_taxname>
#           <Org-ref_db>
#             <Dbtag>
#               <Dbtag_db>taxon</Dbtag_db>
#               <Dbtag_tag>
#                 <Object-id>
#                   <Object-id_id>93061</Object-id_id>
#                 </Object-id>
#               </Dbtag_tag>
#             </Dbtag>
#           </Org-ref_db>
#           <Org-ref_orgname>
#             <OrgName>
#               <OrgName_name>
#                 <OrgName_name_binomial>
#                   <BinomialOrgName>
#                     <BinomialOrgName_genus>Staphylococcus</BinomialOrgName_genus>
#                     <BinomialOrgName_species>aureus</BinomialOrgName_species>
#                     <BinomialOrgName_subspecies>subsp. aureus</BinomialOrgName_subspecies>
#                   </BinomialOrgName>
#                 </OrgName_name_binomial>
#               </OrgName_name>
#               <OrgName_mod>
#                 <OrgMod>
#                   <OrgMod_subtype value="strain">2</OrgMod_subtype>
#                   <OrgMod_subname>NCTC 8325</OrgMod_subname>
#                 </OrgMod>
#                 <OrgMod>
#                   <OrgMod_subtype value="sub-species">22</OrgMod_subtype>
#                   <OrgMod_subname>aureus</OrgMod_subname>
#                 </OrgMod>
#               </OrgName_mod>
#               <OrgName_lineage>Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus</OrgName_lineage>
#               <OrgName_gcode>11</OrgName_gcode>
#               <OrgName_div>BCT</OrgName_div>
#             </OrgName>
#           </Org-ref_orgname>
#         </Org-ref>
#       </BioSource_org>
#     </BioSource>
#   </Entrezgene_source>
#   <Entrezgene_gene>
#     <Gene-ref>
#       <Gene-ref_locus-tag>SAOUHSC_3042a</Gene-ref_locus-tag>
#     </Gene-ref>
#   </Entrezgene_gene>
#   <Entrezgene_prot>
#     <Prot-ref>
#       <Prot-ref_name>
#         <Prot-ref_name_E>SAOUHSC_13820</Prot-ref_name_E>
#       </Prot-ref_name>
#     </Prot-ref>
#   </Entrezgene_prot>
#   <Entrezgene_gene-source>
#     <Gene-source>
#       <Gene-source_src>Entrez Genomes</Gene-source_src>
#       <Gene-source_src-int>88193823</Gene-source_src-int>
#       <Gene-source_src-str1>NC_007795</Gene-source_src-str1>
#       <Gene-source_src-str2>SAOUHSC_3042a</Gene-source_src-str2>
#     </Gene-source>
#   </Entrezgene_gene-source>
#   <Entrezgene_locus>
#     <Gene-commentary>
#       <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#       <Gene-commentary_accession>NC_007795</Gene-commentary_accession>
#       <Gene-commentary_version>1</Gene-commentary_version>
#       <Gene-commentary_seqs>
#         <Seq-loc>
#           <Seq-loc_int>
#             <Seq-interval>
#               <Seq-interval_from>2812462</Seq-interval_from>
#               <Seq-interval_to>2812653</Seq-interval_to>
#               <Seq-interval_strand>
#                 <Na-strand value="plus"/>
#               </Seq-interval_strand>
#               <Seq-interval_id>
#                 <Seq-id>
#                   <Seq-id_gi>88193823</Seq-id_gi>
#                 </Seq-id>
#               </Seq-interval_id>
#             </Seq-interval>
#           </Seq-loc_int>
#         </Seq-loc>
#       </Gene-commentary_seqs>
#       <Gene-commentary_products>
#         <Gene-commentary>
#           <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#           <Gene-commentary_label>SAOUHSC_13820</Gene-commentary_label>
#           <Gene-commentary_accession>YP_008530245</Gene-commentary_accession>
#           <Gene-commentary_version>1</Gene-commentary_version>
#           <Gene-commentary_genomic-coords>
#             <Seq-loc>
#               <Seq-loc_int>
#                 <Seq-interval>
#                   <Seq-interval_from>2812462</Seq-interval_from>
#                   <Seq-interval_to>2812653</Seq-interval_to>
#                   <Seq-interval_strand>
#                     <Na-strand value="plus"/>
#                   </Seq-interval_strand>
#                   <Seq-interval_id>
#                     <Seq-id>
#                       <Seq-id_gi>88193823</Seq-id_gi>
#                     </Seq-id>
#                   </Seq-interval_id>
#                 </Seq-interval>
#               </Seq-loc_int>
#             </Seq-loc>
#           </Gene-commentary_genomic-coords>
#           <Gene-commentary_seqs>
#             <Seq-loc>
#               <Seq-loc_whole>
#                 <Seq-id>
#                   <Seq-id_gi>542123278</Seq-id_gi>
#                 </Seq-id>
#               </Seq-loc_whole>
#             </Seq-loc>
#           </Gene-commentary_seqs>
#         </Gene-commentary>
#       </Gene-commentary_products>
#     </Gene-commentary>
#   </Entrezgene_locus>
#   <Entrezgene_comments>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>NCBI Reference Sequences (RefSeq)</Gene-commentary_heading>
#       <Gene-commentary_comment>
#         <Gene-commentary>
#           <Gene-commentary_type value="comment">254</Gene-commentary_type>
#           <Gene-commentary_heading>Genome Annotation</Gene-commentary_heading>
#           <Gene-commentary_products>
#             <Gene-commentary>
#               <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#               <Gene-commentary_heading>Reference assembly</Gene-commentary_heading>
#               <Gene-commentary_accession>NC_007795</Gene-commentary_accession>
#               <Gene-commentary_version>1</Gene-commentary_version>
#               <Gene-commentary_source>
#                 <Other-source>
#                   <Other-source_src>
#                     <Dbtag>
#                       <Dbtag_db>Nucleotide</Dbtag_db>
#                       <Dbtag_tag>
#                         <Object-id>
#                           <Object-id_id>88193823</Object-id_id>
#                         </Object-id>
#                       </Dbtag_tag>
#                     </Dbtag>
#                   </Other-source_src>
#                 </Other-source>
#               </Gene-commentary_source>
#               <Gene-commentary_seqs>
#                 <Seq-loc>
#                   <Seq-loc_int>
#                     <Seq-interval>
#                       <Seq-interval_from>2812462</Seq-interval_from>
#                       <Seq-interval_to>2812653</Seq-interval_to>
#                       <Seq-interval_strand>
#                         <Na-strand value="plus"/>
#                       </Seq-interval_strand>
#                       <Seq-interval_id>
#                         <Seq-id>
#                           <Seq-id_gi>88193823</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-interval_id>
#                     </Seq-interval>
#                   </Seq-loc_int>
#                 </Seq-loc>
#               </Gene-commentary_seqs>
#               <Gene-commentary_products>
#                 <Gene-commentary>
#                   <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#                   <Gene-commentary_heading>Product</Gene-commentary_heading>
#                   <Gene-commentary_accession>YP_008530245</Gene-commentary_accession>
#                   <Gene-commentary_version>1</Gene-commentary_version>
#                   <Gene-commentary_source>
#                     <Other-source>
#                       <Other-source_src>
#                         <Dbtag>
#                           <Dbtag_db>Protein</Dbtag_db>
#                           <Dbtag_tag>
#                             <Object-id>
#                               <Object-id_id>542123278</Object-id_id>
#                             </Object-id>
#                           </Dbtag_tag>
#                         </Dbtag>
#                       </Other-source_src>
#                       <Other-source_anchor>YP_008530245</Other-source_anchor>
#                       <Other-source_post-text>SAOUHSC_13820 [Staphylococcus aureus subsp. aureus NCTC 8325]</Other-source_post-text>
#                     </Other-source>
#                   </Gene-commentary_source>
#                   <Gene-commentary_seqs>
#                     <Seq-loc>
#                       <Seq-loc_whole>
#                         <Seq-id>
#                           <Seq-id_gi>542123278</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-loc_whole>
#                     </Seq-loc>
#                   </Gene-commentary_seqs>
#                   <Gene-commentary_comment>
#                     <Gene-commentary>
#                       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#                       <Gene-commentary_label>RefSeq Status</Gene-commentary_label>
#                       <Gene-commentary_text>REVIEWED</Gene-commentary_text>
#                     </Gene-commentary>
#                   </Gene-commentary_comment>
#                 </Gene-commentary>
#               </Gene-commentary_products>
#             </Gene-commentary>
#           </Gene-commentary_products>
#         </Gene-commentary>
#       </Gene-commentary_comment>
#     </Gene-commentary>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>RefSeq Status</Gene-commentary_heading>
#       <Gene-commentary_label>REVIEWED</Gene-commentary_label>
#     </Gene-commentary>
#   </Entrezgene_comments>
#   <Entrezgene_unique-keys></Entrezgene_unique-keys>
#   <Entrezgene_xtra-iq></Entrezgene_xtra-iq>
#   <Entrezgene_non-unique-keys>
#     <Dbtag>
#       <Dbtag_db>ID</Dbtag_db>
#       <Dbtag_tag>
#         <Object-id>
#           <Object-id_id>88193823</Object-id_id>
#         </Object-id>
#       </Dbtag_tag>
#     </Dbtag>
#   </Entrezgene_non-unique-keys>
# </Entrezgene>
# </Entrezgene-Set>
# <h1>Staphylococcus aureus</h1><p>24 pubmeds found</p><h3> Genes: </h3>
# CPU times: user 40 ms, sys: 4 ms, total: 44 ms
# Wall time: 1.14 s

# %%
list_genes('GCF_000013465.1', 10, True)
# Out:
# False
# <?xml version="1.0" ?>
# <!DOCTYPE Entrezgene-Set PUBLIC "-//NLM//DTD NCBI-Entrezgene, 21st January 2005//EN" "https://www.ncbi.nlm.nih.gov/data_specs/dtd/NCBI_Entrezgene.dtd">
# <Entrezgene-Set>
# <Entrezgene>
#   <Entrezgene_track-info>
#     <Gene-track>
#       <Gene-track_geneid>31215633</Gene-track_geneid>
#       <Gene-track_create-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2017</Date-std_year>
#               <Date-std_month>3</Date-std_month>
#               <Date-std_day>5</Date-std_day>
#               <Date-std_hour>13</Date-std_hour>
#               <Date-std_minute>33</Date-std_minute>
#               <Date-std_second>0</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_create-date>
#       <Gene-track_update-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2017</Date-std_year>
#               <Date-std_month>9</Date-std_month>
#               <Date-std_day>8</Date-std_day>
#               <Date-std_hour>14</Date-std_hour>
#               <Date-std_minute>32</Date-std_minute>
#               <Date-std_second>0</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_update-date>
#     </Gene-track>
#   </Entrezgene_track-info>
#   <Entrezgene_type value="protein-coding">6</Entrezgene_type>
#   <Entrezgene_source>
#     <BioSource>
#       <BioSource_genome value="chromosome">21</BioSource_genome>
#       <BioSource_org>
#         <Org-ref>
#           <Org-ref_taxname>Staphylococcus aureus</Org-ref_taxname>
#           <Org-ref_db>
#             <Dbtag>
#               <Dbtag_db>taxon</Dbtag_db>
#               <Dbtag_tag>
#                 <Object-id>
#                   <Object-id_id>1280</Object-id_id>
#                 </Object-id>
#               </Dbtag_tag>
#             </Dbtag>
#           </Org-ref_db>
#           <Org-ref_syn>
#             <Org-ref_syn_E>Micrococcus aureus</Org-ref_syn_E>
#             <Org-ref_syn_E>Micrococcus pyogenes</Org-ref_syn_E>
#             <Org-ref_syn_E>Staphlococcus pyogenes citreus</Org-ref_syn_E>
#             <Org-ref_syn_E>Staphylococcus pyogenes aureus</Org-ref_syn_E>
#           </Org-ref_syn>
#           <Org-ref_orgname>
#             <OrgName>
#               <OrgName_name>
#                 <OrgName_name_binomial>
#                   <BinomialOrgName>
#                     <BinomialOrgName_genus>Staphylococcus</BinomialOrgName_genus>
#                     <BinomialOrgName_species>aureus</BinomialOrgName_species>
#                   </BinomialOrgName>
#                 </OrgName_name_binomial>
#               </OrgName_name>
#               <OrgName_mod>
#                 <OrgMod>
#                   <OrgMod_subtype value="strain">2</OrgMod_subtype>
#                   <OrgMod_subname>MS4</OrgMod_subname>
#                 </OrgMod>
#                 <OrgMod>
#                   <OrgMod_subtype value="nat-host">21</OrgMod_subtype>
#                   <OrgMod_subname>Homo sapiens</OrgMod_subname>
#                 </OrgMod>
#               </OrgName_mod>
#               <OrgName_lineage>Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus</OrgName_lineage>
#               <OrgName_gcode>11</OrgName_gcode>
#               <OrgName_div>BCT</OrgName_div>
#             </OrgName>
#           </Org-ref_orgname>
#         </Org-ref>
#       </BioSource_org>
#       <BioSource_subtype>
#         <SubSource>
#           <SubSource_subtype value="country">23</SubSource_subtype>
#           <SubSource_name>China: Shenzhen</SubSource_name>
#         </SubSource>
#         <SubSource>
#           <SubSource_subtype value="isolation-source">28</SubSource_subtype>
#           <SubSource_name>the wound exudate of bone fracture</SubSource_name>
#         </SubSource>
#         <SubSource>
#           <SubSource_subtype value="lat-lon">29</SubSource_subtype>
#           <SubSource_name>22.5313 N 113.924 E</SubSource_name>
#         </SubSource>
#         <SubSource>
#           <SubSource_subtype value="collection-date">30</SubSource_subtype>
#           <SubSource_name>05-Jul-2012</SubSource_name>
#         </SubSource>
#         <SubSource>
#           <SubSource_subtype value="collected-by">31</SubSource_subtype>
#           <SubSource_name>Deng Qiwen</SubSource_name>
#         </SubSource>
#       </BioSource_subtype>
#     </BioSource>
#   </Entrezgene_source>
#   <Entrezgene_gene>
#     <Gene-ref>
#       <Gene-ref_locus-tag>NI36_RS14355</Gene-ref_locus-tag>
#     </Gene-ref>
#   </Entrezgene_gene>
#   <Entrezgene_prot>
#     <Prot-ref>
#       <Prot-ref_name>
#         <Prot-ref_name_E>hypothetical protein</Prot-ref_name_E>
#       </Prot-ref_name>
#     </Prot-ref>
#   </Entrezgene_prot>
#   <Entrezgene_gene-source>
#     <Gene-source>
#       <Gene-source_src>Entrez Genomes</Gene-source_src>
#       <Gene-source_src-int>959863495</Gene-source_src-int>
#       <Gene-source_src-str1>NZ_CP009828</Gene-source_src-str1>
#       <Gene-source_src-str2>NI36_RS14355</Gene-source_src-str2>
#     </Gene-source>
#   </Entrezgene_gene-source>
#   <Entrezgene_locus>
#     <Gene-commentary>
#       <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#       <Gene-commentary_accession>NZ_CP009828</Gene-commentary_accession>
#       <Gene-commentary_version>1</Gene-commentary_version>
#       <Gene-commentary_seqs>
#         <Seq-loc>
#           <Seq-loc_int>
#             <Seq-interval>
#               <Seq-interval_from>2703290</Seq-interval_from>
#               <Seq-interval_to>2703367</Seq-interval_to>
#               <Seq-interval_strand>
#                 <Na-strand value="plus"/>
#               </Seq-interval_strand>
#               <Seq-interval_id>
#                 <Seq-id>
#                   <Seq-id_gi>959863495</Seq-id_gi>
#                 </Seq-id>
#               </Seq-interval_id>
#             </Seq-interval>
#           </Seq-loc_int>
#         </Seq-loc>
#       </Gene-commentary_seqs>
#       <Gene-commentary_products>
#         <Gene-commentary>
#           <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#           <Gene-commentary_label>hypothetical protein</Gene-commentary_label>
#           <Gene-commentary_accession>WP_078061161</Gene-commentary_accession>
#           <Gene-commentary_version>1</Gene-commentary_version>
#           <Gene-commentary_genomic-coords>
#             <Seq-loc>
#               <Seq-loc_int>
#                 <Seq-interval>
#                   <Seq-interval_from>2703290</Seq-interval_from>
#                   <Seq-interval_to>2703367</Seq-interval_to>
#                   <Seq-interval_strand>
#                     <Na-strand value="plus"/>
#                   </Seq-interval_strand>
#                   <Seq-interval_id>
#                     <Seq-id>
#                       <Seq-id_gi>959863495</Seq-id_gi>
#                     </Seq-id>
#                   </Seq-interval_id>
#                 </Seq-interval>
#               </Seq-loc_int>
#             </Seq-loc>
#           </Gene-commentary_genomic-coords>
#           <Gene-commentary_seqs>
#             <Seq-loc>
#               <Seq-loc_whole>
#                 <Seq-id>
#                   <Seq-id_gi>1151011228</Seq-id_gi>
#                 </Seq-id>
#               </Seq-loc_whole>
#             </Seq-loc>
#           </Gene-commentary_seqs>
#         </Gene-commentary>
#       </Gene-commentary_products>
#     </Gene-commentary>
#   </Entrezgene_locus>
#   <Entrezgene_comments>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>NCBI Reference Sequences (RefSeq)</Gene-commentary_heading>
#       <Gene-commentary_comment>
#         <Gene-commentary>
#           <Gene-commentary_type value="comment">254</Gene-commentary_type>
#           <Gene-commentary_heading>Genome Annotation</Gene-commentary_heading>
#           <Gene-commentary_products>
#             <Gene-commentary>
#               <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#               <Gene-commentary_heading>Reference assembly</Gene-commentary_heading>
#               <Gene-commentary_accession>NZ_CP009828</Gene-commentary_accession>
#               <Gene-commentary_version>1</Gene-commentary_version>
#               <Gene-commentary_source>
#                 <Other-source>
#                   <Other-source_src>
#                     <Dbtag>
#                       <Dbtag_db>Nucleotide</Dbtag_db>
#                       <Dbtag_tag>
#                         <Object-id>
#                           <Object-id_id>959863495</Object-id_id>
#                         </Object-id>
#                       </Dbtag_tag>
#                     </Dbtag>
#                   </Other-source_src>
#                 </Other-source>
#               </Gene-commentary_source>
#               <Gene-commentary_seqs>
#                 <Seq-loc>
#                   <Seq-loc_int>
#                     <Seq-interval>
#                       <Seq-interval_from>2703290</Seq-interval_from>
#                       <Seq-interval_to>2703367</Seq-interval_to>
#                       <Seq-interval_strand>
#                         <Na-strand value="plus"/>
#                       </Seq-interval_strand>
#                       <Seq-interval_id>
#                         <Seq-id>
#                           <Seq-id_gi>959863495</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-interval_id>
#                     </Seq-interval>
#                   </Seq-loc_int>
#                 </Seq-loc>
#               </Gene-commentary_seqs>
#               <Gene-commentary_products>
#                 <Gene-commentary>
#                   <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#                   <Gene-commentary_heading>Product</Gene-commentary_heading>
#                   <Gene-commentary_accession>WP_078061161</Gene-commentary_accession>
#                   <Gene-commentary_version>1</Gene-commentary_version>
#                   <Gene-commentary_source>
#                     <Other-source>
#                       <Other-source_src>
#                         <Dbtag>
#                           <Dbtag_db>Protein</Dbtag_db>
#                           <Dbtag_tag>
#                             <Object-id>
#                               <Object-id_id>1151011228</Object-id_id>
#                             </Object-id>
#                           </Dbtag_tag>
#                         </Dbtag>
#                       </Other-source_src>
#                       <Other-source_anchor>WP_078061161</Other-source_anchor>
#                       <Other-source_post-text>hypothetical protein NI36_RS14355 [Staphylococcus aureus]</Other-source_post-text>
#                     </Other-source>
#                   </Gene-commentary_source>
#                   <Gene-commentary_seqs>
#                     <Seq-loc>
#                       <Seq-loc_whole>
#                         <Seq-id>
#                           <Seq-id_gi>1151011228</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-loc_whole>
#                     </Seq-loc>
#                   </Gene-commentary_seqs>
#                   <Gene-commentary_comment>
#                     <Gene-commentary>
#                       <Gene-commentary_type value="other">255</Gene-commentary_type>
#                       <Gene-commentary_heading>Conserved Domains</Gene-commentary_heading>
#                       <Gene-commentary_source>
#                         <Other-source>
#                           <Other-source_pre-text>(1)</Other-source_pre-text>
#                           <Other-source_anchor>summary</Other-source_anchor>
#                         </Other-source>
#                       </Gene-commentary_source>
#                       <Gene-commentary_comment>
#                         <Gene-commentary>
#                           <Gene-commentary_type value="other">255</Gene-commentary_type>
#                           <Gene-commentary_source>
#                             <Other-source>
#                               <Other-source_src>
#                                 <Dbtag>
#                                   <Dbtag_db>CDD</Dbtag_db>
#                                   <Dbtag_tag>
#                                     <Object-id>
#                                       <Object-id_id>314300</Object-id_id>
#                                     </Object-id>
#                                   </Dbtag_tag>
#                                 </Dbtag>
#                               </Other-source_src>
#                               <Other-source_anchor>pfam11323: DUF3125; Protein of unknown function (DUF3125)</Other-source_anchor>
#                             </Other-source>
#                           </Gene-commentary_source>
#                           <Gene-commentary_comment>
#                             <Gene-commentary>
#                               <Gene-commentary_type value="other">255</Gene-commentary_type>
#                               <Gene-commentary_text>Location: 1 - 24</Gene-commentary_text>
#                             </Gene-commentary>
#                           </Gene-commentary_comment>
#                         </Gene-commentary>
#                       </Gene-commentary_comment>
#                     </Gene-commentary>
#                   </Gene-commentary_comment>
#                 </Gene-commentary>
#               </Gene-commentary_products>
#             </Gene-commentary>
#           </Gene-commentary_products>
#         </Gene-commentary>
#       </Gene-commentary_comment>
#     </Gene-commentary>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>RefSeq Status</Gene-commentary_heading>
#       <Gene-commentary_label></Gene-commentary_label>
#     </Gene-commentary>
#   </Entrezgene_comments>
#   <Entrezgene_unique-keys></Entrezgene_unique-keys>
#   <Entrezgene_xtra-iq></Entrezgene_xtra-iq>
#   <Entrezgene_non-unique-keys>
#     <Dbtag>
#       <Dbtag_db>ID</Dbtag_db>
#       <Dbtag_tag>
#         <Object-id>
#           <Object-id_id>959863495</Object-id_id>
#         </Object-id>
#       </Dbtag_tag>
#     </Dbtag>
#   </Entrezgene_non-unique-keys>
# </Entrezgene>
# </Entrezgene-Set>
# <h1>Staphylococcus aureus</h1><p>24 pubmeds found</p><h3> Genes: </h3>

# %%
list_genes('GCF_000013425.1', 50, True)
# Out:
# <h1>Staphylococcus aureus</h1><p>24 pubmeds found</p><h3> Genes: </h3><table><tr><th> Gene Tag </th><th> Gene Locus </th><th> Protein </th><th> Protein sequence </th><th> Number of Pubmed publications </th></tr><tr><td>NI36_RS14355</td><td>n/a</td><td>hypothetical protein</td><td>WP_078061161.1</td><td>0</td></tr><tr><td>NI36_RS14350</td><td>n/a</td><td>hypothetical protein</td><td>WP_071621415.1</td><td>0</td></tr><tr><td>NI36_RS14345</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14340</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14335</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14330</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14325</td><td>n/a</td><td>hypothetical protein</td><td>WP_078065189.1</td><td>0</td></tr><tr><td>NI36_RS14320</td><td>n/a</td><td>hypothetical protein</td><td>WP_001228565.1</td><td>0</td></tr><tr><td>NI36_RS14315</td><td>n/a</td><td>DUF2648 domain-containing protein</td><td>WP_000731972.1</td><td>0</td></tr><tr><td>NI36_RS14310</td><td>n/a</td><td>hypothetical protein</td><td>WP_001803564.1</td><td>0</td></tr><tr><td>NI36_RS14305</td><td>n/a</td><td>hypothetical protein</td><td>WP_078065156.1</td><td>0</td></tr><tr><td>NI36_RS14300</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14295</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14290</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665647.1</td><td>0</td></tr><tr><td>NI36_RS14285</td><td>n/a</td><td>hypothetical protein</td><td>WP_001621913.1</td><td>0</td></tr><tr><td>NI36_RS14280</td><td>n/a</td><td>hypothetical protein</td><td>WP_078065154.1</td><td>0</td></tr><tr><td>NI36_RS14275</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14270</td><td>n/a</td><td>hypothetical protein</td><td>WP_001792003.1</td><td>0</td></tr><tr><td>NI36_RS14265</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665669.1</td><td>0</td></tr><tr><td>NI36_RS14260</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665646.1</td><td>0</td></tr><tr><td>NI36_RS14255</td><td>n/a</td><td>hypothetical protein</td><td>WP_031845057.1</td><td>0</td></tr><tr><td>NI36_RS14250</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14245</td><td>n/a</td><td>hypothetical protein</td><td>WP_001789152.1</td><td>0</td></tr><tr><td>NI36_RS14240</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665644.1</td><td>0</td></tr><tr><td>NI36_RS14235</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665643.1</td><td>0</td></tr><tr><td>NI36_RS14230</td><td>n/a</td><td>hypothetical protein</td><td>WP_031927355.1</td><td>0</td></tr><tr><td>NI36_RS14225</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14220</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665642.1</td><td>0</td></tr><tr><td>NI36_RS14215</td><td>n/a</td><td>hypothetical protein</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14210</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14205</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14200</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14195</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14190</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14185</td><td>n/a</td><td>hypothetical protein</td><td>WP_000312015.1</td><td>0</td></tr><tr><td>NI36_RS14180</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665667.1</td><td>0</td></tr><tr><td>NI36_RS14175</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665666.1</td><td>0</td></tr><tr><td>NI36_RS14170</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665640.1</td><td>0</td></tr><tr><td>NI36_RS14165</td><td>n/a</td><td>n/a</td><td>n/a.n/a</td><td>0</td></tr><tr><td>NI36_RS14160</td><td>n/a</td><td>hypothetical protein</td><td>WP_071665639.1</t ...
